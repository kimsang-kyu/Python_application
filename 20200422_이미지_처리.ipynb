# %% [markdown]
# <a href="https://colab.research.google.com/github/kimsang-kyu/Python_application/blob/main/20200422_%EC%9D%B4%EB%AF%B8%EC%A7%80_%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Library-OpenCV

# %%
#라이브러리 설치
# !pip install opencv-python

# %%
import cv2

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
#파일 탐색기 사용
from tkinter.filedialog import askopenfilename

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
img_file = '/content/drive/My Drive/파이썬활용/sample-color.png'
img_file
# Out:
# '/content/drive/My Drive/파이썬활용/sample-color.png'

# %% [markdown]
# #이미지로드

# %%
image_bgr = cv2.imread(img_file)

#RGB로 변환
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

#이미치 출력
plt.figure(figsize=(20,10))
plt.imshow(image_rgb)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# !.[image.png].(attachment:image.png)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `attachment:image.png'
# /bin/bash: -c: line 0: `.[image.png].(attachment:image.png)'

# %%
# 픽셀 확인
image_bgr[0,0,:]

#이미지는 4사분면에 표시가 된다.
# Out:
# array([ 88, 116, 116], dtype=uint8)

# %%
image_bgr.shape
# Out:
# (512, 768, 3)

# %%
#흑백이미지
image = cv2.imread(img_file, cv2.IMREAD_GRAYSCALE) #gray_scale

# %%
image.shape
# Out:
# (512, 768)

# %%
#
plt.figure(figsize=(20,10))
plt.imshow(image,'gray')
plt.show()
